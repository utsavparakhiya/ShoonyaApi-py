# %%
indices_array = ['BANKNIFTY', 'NIFTY', 'FINNIFTY', 'MIDCPNIFTY', 'SENSEX']
indices_lot_size = [15, 50, 40, 75, 10]
changes_in_Strike = [100, 50, 50, 25, 100]
sensex_expiry_date = '2024-04-19'

# %%
from NorenRestApiPy.NorenApi import  NorenApi

class ShoonyaApiPy(NorenApi):
    def __init__(self):
        NorenApi.__init__(self, host='https://api.shoonya.com/NorenWClientTP/', websocket='wss://api.shoonya.com/NorenWSTP/')        
        global api
        api = self

# %%
import pyotp

api = ShoonyaApiPy()

# %%
id = 4
lots = 2
lower_limit = 74000.00
upper_limit = 76000.00

index = indices_array[id]
lot_size = indices_lot_size[id]

# %%
user = "FA267228"
pwd = "Meet@1811"
vc = "FA267228_U"
app_key = "6ebfa36708493ccaed011fdd2ebe2298"
token = "Q7USK6X664V5544L5NB45HM3N7UU5K4A"

# %%
api = ShoonyaApiPy()
ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')

with open('session_token.txt','w') as file:
    file.write(ret['susertoken'])
print(ret)
# Out:
# {'request_time': '10:11:03 13-04-2024', 'actid': 'FA267228', 'access_type': ['WEB', 'TT', 'MOB', 'API'], 'uname': 'PUSHPABEN ARVINDBHAI VARSADA', 'prarr': [{'prd': 'C', 's_prdt_ali': 'CNC', 'exch': ['NSE', 'BSE', 'NIPO', 'BSTAR']}, {'prd': 'M', 's_prdt_ali': 'NRML', 'exch': ['NFO', 'BFO', 'CDS', 'BCD', 'MCX']}, {'prd': 'I', 's_prdt_ali': 'MIS', 'exch': ['NSE', 'BSE', 'NFO', 'BFO', 'CDS', 'BCD', 'MCX']}, {'prd': 'H', 's_prdt_ali': 'CO', 'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']}, {'prd': 'B', 's_prdt_ali': 'BO', 'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']}], 'exch_prd': [{'exch': 'NSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'NIPO', 'prds': ['C']}, {'exch': 'NFO', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'CDS', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'BSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'BCD', 'prds': ['M', 'I']}, {'exch': 'MCX', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'BSTAR', 'prds': ['C']}, {'exch': 'BFO', 'prds': ['M', 'I']}], 'stat': 'Ok', 'susertoken': '30cb1e3b28be9d5cbfde19ad4fa7f1958d7494e59dbdf7eba45ccdb1be165615', 'email': 'meetvarsada18@gmail.com', 'uid': 'FA267228', 'brnchid': 'HO', 'totp_set': '1', 'm_num': '8487944244', 'orarr': ['MKT', 'LMT', 'SL-LMT', 'SL-MKT'], 'exarr': ['NSE', 'NIPO', 'NFO', 'CDS', 'BSE', 'BCD', 'MCX', 'BSTAR', 'BFO'], 'values': ['1'], 'mws': {'1': []}, 'brkname': 'FINV', 'dmsg': '', 'lastaccesstime': '1712983263'}

# %%
# ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')
session_token = open('session_token.txt','r').read()
print(len(session_token))
api.set_session(user, pwd, session_token)
api.get_limits()
# Out:
# 64
# {'request_time': '10:11:03 13-04-2024',
#  'stat': 'Ok',
#  'prfname': 'SHOONYA',
#  'cash': '0.00',
#  'payin': '0.00',
#  'payout': '0.00',
#  'brkcollamt': '0.00',
#  'unclearedcash': '0.00',
#  'aux_daycash': '0.00',
#  'aux_brkcollamt': '0.00',
#  'aux_unclearedcash': '0.00',
#  'daycash': '0.00',
#  'turnoverlmt': '999999999999.00',
#  'pendordvallmt': '999999999999.00',
#  'remarks_amt': '0.00',
#  'blk_amt': '0.00'}

# %%
import pandas as pd
from datetime import datetime,date
nfo_url = 'https://api.shoonya.com/NFO_symbols.txt.zip'
bfo_url = 'https://api.shoonya.com/BFO_symbols.txt.zip'
symbolDf = pd.read_csv(bfo_url if index == 'SENSEX' else nfo_url)
symbolDf['Expiry'] = pd.to_datetime(symbolDf['Expiry']).apply(lambda x: x.date())   
symbolDf
# Out:
#       Exchange    Token  LotSize   Symbol   TradingSymbol      Expiry  \
# 0          BFO   862590     3000  ZEELOPT  ZEEL24MAY195PE  2024-05-30
# 1          BFO   862428     3000  ZEELOPT  ZEEL24MAY190PE  2024-05-30
# 2          BFO   864006     3000  ZEELOPT  ZEEL24MAY185PE  2024-05-30
# 3          BFO   863849     3000  ZEELOPT  ZEEL24MAY180PE  2024-05-30
# 4          BFO   865414     3000  ZEELOPT  ZEEL24MAY175PE  2024-05-30
# ...        ...      ...      ...      ...             ...         ...
# 37512      BFO  2011080      125  ABBLOPT  ABB24APR4200CE  2024-04-25
# 37513      BFO  2042441      125  ABBLOPT  ABB24APR4150CE  2024-04-25
# 37514      BFO  2019451      125  ABBLOPT  ABB24APR4100CE  2024-04-25
# 37515      BFO  2051002      125  ABBLOPT  ABB24APR4050CE  2024-04-25
# 37516      BFO  2022027      125  ABBLOPT  ABB24APR4000CE  2024-04-25
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 0         OPTSTK         PE        195.0      0.05          NaN
# 1         OPTSTK         PE        190.0      0.05          NaN
# 2         OPTSTK         PE        185.0      0.05          NaN
# 3         OPTSTK         PE        180.0      0.05          NaN
# 4         OPTSTK         PE        175.0      0.05          NaN
# ...          ...        ...          ...       ...          ...
# 37512     OPTSTK         CE       4200.0      0.05          NaN
# 37513     OPTSTK         CE       4150.0      0.05          NaN
# 37514     OPTSTK         CE       4100.0      0.05          NaN
# 37515     OPTSTK         CE       4050.0      0.05          NaN
# 37516     OPTSTK         CE       4000.0      0.05          NaN
#
# [37517 rows x 11 columns]

# %%
def get_expiry_dates(exchange, symbol):
    import re
    import datetime
    sd = api.searchscrip(exchange, symbol)
    sd = (sd['values'])
    tsym_values = [Symbol['tsym'] for Symbol in sd]
    dates = [re.search(r'\d+[A-Z]{3}\d+', tsym).group() for tsym in tsym_values]
    formatted_dates = [datetime.datetime.strptime(date, '%d%b%y').strftime('%Y-%m-%d') for date in dates]
    sorted_formatted_dates = sorted(formatted_dates)
    expiry_dates = sorted_formatted_dates
#     sorted_dates = [datetime.datetime.strptime(date, '%Y-%m-%d').strftime('%d%b%y').upper() for date in sorted_formatted_dates]
#     expiry_dates = sorted_dates
    return expiry_dates

expiry_date = sensex_expiry_date if index == 'SENSEX' else get_expiry_dates('BFO' if index == 'SENSEX' else 'NFO', index)[0]
print(expiry_date)
# Out:
# 2024-04-19

# %%
date_object = datetime.strptime(expiry_date, "%Y-%m-%d").date()

ocdf = symbolDf[(symbolDf.Symbol == ('BSXOPT' if index == 'SENSEX' else index)) & (symbolDf.Expiry == date_object)]
ocdf
# Out:
#       Exchange   Token  LotSize  Symbol       TradingSymbol      Expiry  \
# 28959      BFO  881010       10  BSXOPT  SENSEX2441978000PE  2024-04-19
# 28960      BFO  880851       10  BSXOPT  SENSEX2441977900PE  2024-04-19
# 28961      BFO  880918       10  BSXOPT  SENSEX2441977800PE  2024-04-19
# 28962      BFO  880391       10  BSXOPT  SENSEX2441977700PE  2024-04-19
# 28963      BFO  880475       10  BSXOPT  SENSEX2441977600PE  2024-04-19
# ...        ...     ...      ...     ...                 ...         ...
# 29136      BFO  869973       10  BSXOPT  SENSEX2441969400CE  2024-04-19
# 29137      BFO  870099       10  BSXOPT  SENSEX2441969300CE  2024-04-19
# 29138      BFO  869959       10  BSXOPT  SENSEX2441969200CE  2024-04-19
# 29139      BFO  870089       10  BSXOPT  SENSEX2441969100CE  2024-04-19
# 29140      BFO  869946       10  BSXOPT  SENSEX2441969000CE  2024-04-19
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 28959     OPTIDX         PE      78000.0      0.05          NaN
# 28960     OPTIDX         PE      77900.0      0.05          NaN
# 28961     OPTIDX         PE      77800.0      0.05          NaN
# 28962     OPTIDX         PE      77700.0      0.05          NaN
# 28963     OPTIDX         PE      77600.0      0.05          NaN
# ...          ...        ...          ...       ...          ...
# 29136     OPTIDX         CE      69400.0      0.05          NaN
# 29137     OPTIDX         CE      69300.0      0.05          NaN
# 29138     OPTIDX         CE      69200.0      0.05          NaN
# 29139     OPTIDX         CE      69100.0      0.05          NaN
# 29140     OPTIDX         CE      69000.0      0.05          NaN
#
# [182 rows x 11 columns]

# %%
len(ocdf)
# Out:
# 182

# %%
Cedf =ocdf[(ocdf.OptionType == 'CE')& (ocdf['StrikePrice'] > lower_limit) & (ocdf['StrikePrice'] < upper_limit)] 
Cedf
# Out:
#       Exchange   Token  LotSize  Symbol       TradingSymbol      Expiry  \
# 29071      BFO  867003       10  BSXOPT  SENSEX2441975900CE  2024-04-19
# 29072      BFO  867090       10  BSXOPT  SENSEX2441975800CE  2024-04-19
# 29073      BFO  866870       10  BSXOPT  SENSEX2441975700CE  2024-04-19
# 29074      BFO  866949       10  BSXOPT  SENSEX2441975600CE  2024-04-19
# 29075      BFO  866751       10  BSXOPT  SENSEX2441975500CE  2024-04-19
# 29076      BFO  867192       10  BSXOPT  SENSEX2441975400CE  2024-04-19
# 29077      BFO  867282       10  BSXOPT  SENSEX2441975300CE  2024-04-19
# 29078      BFO  867048       10  BSXOPT  SENSEX2441975200CE  2024-04-19
# 29079      BFO  867134       10  BSXOPT  SENSEX2441975100CE  2024-04-19
# 29080      BFO  866912       10  BSXOPT  SENSEX2441975000CE  2024-04-19
# 29081      BFO  866839       10  BSXOPT  SENSEX2441974900CE  2024-04-19
# 29082      BFO  866905       10  BSXOPT  SENSEX2441974800CE  2024-04-19
# 29083      BFO  867367       10  BSXOPT  SENSEX2441974700CE  2024-04-19
# 29084      BFO  867149       10  BSXOPT  SENSEX2441974600CE  2024-04-19
# 29085      BFO  867239       10  BSXOPT  SENSEX2441974500CE  2024-04-19
# 29086      BFO  867005       10  BSXOPT  SENSEX2441974400CE  2024-04-19
# 29087      BFO  867092       10  BSXOPT  SENSEX2441974300CE  2024-04-19
# 29088      BFO  866872       10  BSXOPT  SENSEX2441974200CE  2024-04-19
# 29089      BFO  867334       10  BSXOPT  SENSEX2441974100CE  2024-04-19
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 29071     OPTIDX         CE      75900.0      0.05          NaN
# 29072     OPTIDX         CE      75800.0      0.05          NaN
# 29073     OPTIDX         CE      75700.0      0.05          NaN
# 29074     OPTIDX         CE      75600.0      0.05          NaN
# 29075     OPTIDX         CE      75500.0      0.05          NaN
# 29076     OPTIDX         CE      75400.0      0.05          NaN
# 29077     OPTIDX         CE      75300.0      0.05          NaN
# 29078     OPTIDX         CE      75200.0      0.05          NaN
# 29079     OPTIDX         CE      75100.0      0.05          NaN
# 29080     OPTIDX         CE      75000.0      0.05          NaN
# 29081     OPTIDX         CE      74900.0      0.05          NaN
# 29082     OPTIDX         CE      74800.0      0.05          NaN
# 29083     OPTIDX         CE      74700.0      0.05          NaN
# 29084     OPTIDX         CE      74600.0      0.05          NaN
# 29085     OPTIDX         CE      74500.0      0.05          NaN
# 29086     OPTIDX         CE      74400.0      0.05          NaN
# 29087     OPTIDX         CE      74300.0      0.05          NaN
# 29088     OPTIDX         CE      74200.0      0.05          NaN
# 29089     OPTIDX         CE      74100.0      0.05          NaN

# %%
Pedf =ocdf[(ocdf.OptionType == 'PE') & (ocdf['StrikePrice'] > lower_limit) & (ocdf['StrikePrice'] < upper_limit)] 
Pedf
# Out:
#       Exchange   Token  LotSize  Symbol       TradingSymbol      Expiry  \
# 28980      BFO  866970       10  BSXOPT  SENSEX2441975900PE  2024-04-19
# 28981      BFO  866776       10  BSXOPT  SENSEX2441975800PE  2024-04-19
# 28982      BFO  867222       10  BSXOPT  SENSEX2441975700PE  2024-04-19
# 28983      BFO  867306       10  BSXOPT  SENSEX2441975600PE  2024-04-19
# 28984      BFO  867076       10  BSXOPT  SENSEX2441975500PE  2024-04-19
# 28985      BFO  867161       10  BSXOPT  SENSEX2441975400PE  2024-04-19
# 28986      BFO  866935       10  BSXOPT  SENSEX2441975300PE  2024-04-19
# 28987      BFO  866739       10  BSXOPT  SENSEX2441975200PE  2024-04-19
# 28988      BFO  866817       10  BSXOPT  SENSEX2441975100PE  2024-04-19
# 28989      BFO  867270       10  BSXOPT  SENSEX2441975000PE  2024-04-19
# 28990      BFO  867175       10  BSXOPT  SENSEX2441974900PE  2024-04-19
# 28991      BFO  867263       10  BSXOPT  SENSEX2441974800PE  2024-04-19
# 28992      BFO  867030       10  BSXOPT  SENSEX2441974700PE  2024-04-19
# 28993      BFO  867117       10  BSXOPT  SENSEX2441974600PE  2024-04-19
# 28994      BFO  866894       10  BSXOPT  SENSEX2441974500PE  2024-04-19
# 28995      BFO  867357       10  BSXOPT  SENSEX2441974400PE  2024-04-19
# 28996      BFO  866778       10  BSXOPT  SENSEX2441974300PE  2024-04-19
# 28997      BFO  867225       10  BSXOPT  SENSEX2441974200PE  2024-04-19
# 28998      BFO  867307       10  BSXOPT  SENSEX2441974100PE  2024-04-19
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 28980     OPTIDX         PE      75900.0      0.05          NaN
# 28981     OPTIDX         PE      75800.0      0.05          NaN
# 28982     OPTIDX         PE      75700.0      0.05          NaN
# 28983     OPTIDX         PE      75600.0      0.05          NaN
# 28984     OPTIDX         PE      75500.0      0.05          NaN
# 28985     OPTIDX         PE      75400.0      0.05          NaN
# 28986     OPTIDX         PE      75300.0      0.05          NaN
# 28987     OPTIDX         PE      75200.0      0.05          NaN
# 28988     OPTIDX         PE      75100.0      0.05          NaN
# 28989     OPTIDX         PE      75000.0      0.05          NaN
# 28990     OPTIDX         PE      74900.0      0.05          NaN
# 28991     OPTIDX         PE      74800.0      0.05          NaN
# 28992     OPTIDX         PE      74700.0      0.05          NaN
# 28993     OPTIDX         PE      74600.0      0.05          NaN
# 28994     OPTIDX         PE      74500.0      0.05          NaN
# 28995     OPTIDX         PE      74400.0      0.05          NaN
# 28996     OPTIDX         PE      74300.0      0.05          NaN
# 28997     OPTIDX         PE      74200.0      0.05          NaN
# 28998     OPTIDX         PE      74100.0      0.05          NaN

# %%
api.get_quotes(exchange='BFO', token='867307')
# Out:
# {'request_time': '10:19:24 13-04-2024',
#  'stat': 'Ok',
#  'exch': 'BFO',
#  'tsym': 'SENSEX2441974100PE',
#  'symname': 'BSXOPT',
#  'seg': 'DER',
#  'exd': '19-APR-2024',
#  'instname': 'OPTIDX',
#  'optt': 'PE',
#  'pp': '2',
#  'ls': '10',
#  'ti': '0.05',
#  'mult': '1',
#  'lut': '1712983607',
#  'uc': '1283.95',
#  'lc': '0.05',
#  'oi': '5840',
#  'cutof_all': 'false',
#  'strprc': '74100.00',
#  'prcftr_d': '(1 / 1 ) * (1 / 1)',
#  'token': '867307',
#  'c': '345.05',
#  'ltt': '00:00:00',
#  'ltd': '13-04-2024',
#  'und_exch': 'BSE',
#  'und_tk': '1'}

# %%
api.get_quotes(exchange='NFO', token='67521')
# Out:
# {'request_time': '10:14:12 13-04-2024',
#  'stat': 'Ok',
#  'exch': 'NFO',
#  'tsym': 'BANKNIFTY24APR24P47700',
#  'cname': 'BANKNIFTY 24APR24 47700 PE ',
#  'symname': 'BANKNIFTY',
#  'seg': 'DER',
#  'exd': '24-APR-2024',
#  'instname': 'OPTIDX',
#  'optt': 'PE',
#  'pp': '2',
#  'ls': '15',
#  'ti': '0.05',
#  'mult': '1',
#  'uc': '500.15',
#  'lc': '0.05',
#  'oi': '60960',
#  'cutof_all': 'false',
#  'strprc': '47700.00',
#  'prcftr_d': '(1 / 1 ) * (1 / 1)',
#  'token': '67521',
#  'lp': '140.20',
#  'c': '140.20',
#  'und_exch': 'NSE',
#  'und_tk': '26009'}

# %%
expiry_date
from datetime import datetime
date_obj = datetime.strptime(expiry_date, "%Y-%m-%d")
today = datetime.now()
diff = (date_obj - today).days
print(diff)
# Out:
# 5

# %%
sell_premium = {
    "MIDCPNIFTY":[15,15,20,25,30],
    "FINNIFTY":[25,30,35,40,45],
    "NIFTY":[25,30,35,40,45],
    "BANKNIFTY": [50, 60,70,80,90,100],
    "SENSEX":[70,80,100,120,140,15,15,15]
}

# %%
buy_premium = {
    "MIDCPNIFTY":[2,2,3,3,3],
    "FINNIFTY":[3,4,4,5,5],
    "NIFTY":[3,4,4,5,5],
    "BANKNIFTY": [5,10,10,15,15],
    "SENSEX":[5,10,15,15,15,15,15,15]
}

# %%
ltp1 = buy_premium[index][diff]
ltp = sell_premium[index][diff]

print(ltp1)
print(ltp)
strikeList = []
for i in Cedf.index:
    strikeInfo = Cedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
    
strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf1['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
ce_buy = strikedf1.iloc[0].tsym
print(ce_buy)

strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
ce_sell = strikedf.iloc[0].tsym
print(ce_sell)
ce_sl = 2*(strikedf.iloc[0].lp)
print(ce_sl)
# Out:
# 15
# 15
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\UTSAVP~1\AppData\Local\Temp/ipykernel_4804/2449210018.py in <module>
#       8     strikeInfo = Cedf.loc[i]
#       9     res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
# ---> 10     res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
#      11     strikeList.append(res)
#      12
#
# TypeError: 'NoneType' object is not subscriptable

# %%
ltp = buy_premium[index][diff]
ltp1 = sell_premium[index][diff]

print(ltp)
print(ltp1)

strikeList = []
for i in Pedf.index:
    strikeInfo = Pedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
pe_buy = strikedf.iloc[0].tsym
print(pe_buy)

strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
pe_sell = strikedf1.iloc[0].tsym
print(pe_sell)
pe_sl = 2*(strikedf1.iloc[0].lp)
print(pe_sl)

# %%
# ltp = sell_premium[index][diff]
# print(ltp)

# strikeList = []
# for i in Cedf.index:
#     strikeInfo = Cedf.loc[i]
#     res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
#     res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
#     strikeList.append(res)
# strikedf = pd.DataFrame(strikeList)
# strikedf.sort_values(by = 'lp',inplace = True)
# strikedf['diff'] = abs(strikedf['lp'] - ltp)
# strikedf.sort_values(by = 'diff',inplace = True)
# ce_sell = strikedf.iloc[0].tsym

# %%
# ltp = sell_premium[index][diff]
# print(ltp)

# strikeList = []
# for i in Pedf.index:
#     strikeInfo = Pedf.loc[i]
#     res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
#     res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
#     strikeList.append(res)
# strikedf = pd.DataFrame(strikeList)
# strikedf.sort_values(by = 'lp',inplace = True)
# strikedf['diff'] = abs(strikedf['lp'] - ltp)
# strikedf.sort_values(by = 'diff',inplace = True)
# pe_sell = strikedf.iloc[0].tsym

# %%
print(ce_buy)
print(pe_buy)
print(ce_sell)
print(pe_sell)

# %%
import re

def get_new_strike(original_string, change):
    import re
    match = re.search(r'\d+$', original_string)

    if match:
        # Extracted number
        number = int(match.group())

        # Add 100 to the number
        new_number = number + change

        # Replace the old number with the new number in the original string
        new_string = original_string[:match.start()] + str(new_number)
        
        print("Original string:", original_string)
        print("New string:", new_string)
        return new_string        
    else:
        print("Strike not in proper format")

# %%
# call buy leg
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

# %%
# put buy leg
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

# %%
# call sell leg
ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

# %%
# put sell leg
ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

# %%
# call sl order
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']

# %%
# put sl order
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']

# %%
print(ce_sl_orderid)
print(pe_sl_orderid)

# %%
# # call adj1
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # call adj2
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # call adj3
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # call adj4
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # put adj1
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']

# %%
# # put adj2
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']

# %%
# # put adj3
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']

# %%
# # put adj4
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']
