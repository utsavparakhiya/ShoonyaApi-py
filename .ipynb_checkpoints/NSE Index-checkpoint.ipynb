# %%
indices_array = ['BANKNIFTY', 'NIFTY', 'FINNIFTY', 'MIDCPNIFTY']
indices_lot_size = [15, 50, 40, 75]

# %%
from NorenRestApiPy.NorenApi import  NorenApi

class ShoonyaApiPy(NorenApi):
    def __init__(self):
        NorenApi.__init__(self, host='https://api.shoonya.com/NorenWClientTP/', websocket='wss://api.shoonya.com/NorenWSTP/')        
        global api
        api = self

# %%
import pyotp

api = ShoonyaApiPy()

# %%
index = "BANKNIFTY"

# %%
user = "FA178801"
pwd = "J@su120573"
vc = "FA178801_U"
app_key = "ccfb9759459dc69f44e293328606a78b"
token = "YP5547Q565DAT5753NBH54K72J234SC5"
lots = 2
lot_size = 15
lower_limit = 45400.00
upper_limit = 51000.00

# %%
api = ShoonyaApiPy()
ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')

with open('session_token.txt','w') as file:
    file.write(ret['susertoken'])
print(ret)
# Out:
# {'request_time': '11:29:38 07-04-2024', 'actid': 'FA178801', 'access_type': ['WEB', 'TT', 'MOB', 'API'], 'uname': 'PARAKHIYA UTSAV RAMESHBHAI', 'prarr': [{'prd': 'C', 's_prdt_ali': 'CNC', 'exch': ['NSE', 'BSE', 'NIPO', 'BSTAR']}, {'prd': 'M', 's_prdt_ali': 'NRML', 'exch': ['NFO', 'BFO']}, {'prd': 'I', 's_prdt_ali': 'MIS', 'exch': ['NSE', 'BSE', 'NFO', 'BFO']}, {'prd': 'H', 's_prdt_ali': 'CO', 'exch': ['NSE', 'NFO', 'BSE']}, {'prd': 'B', 's_prdt_ali': 'BO', 'exch': ['NSE', 'NFO', 'BSE']}], 'exch_prd': [{'exch': 'NSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'NIPO', 'prds': ['C']}, {'exch': 'BSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'BSTAR', 'prds': ['C']}, {'exch': 'NFO', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'BFO', 'prds': ['M', 'I']}], 'stat': 'Ok', 'susertoken': 'edc6cd3a649696a8e86c0c5a4cfd9ef789aacd0c97e9d8ed1db11460d3197ff5', 'email': 'utsavparakhiya6933@gmail.com', 'uid': 'FA178801', 'brnchid': 'HO', 'totp_set': '1', 'm_num': '9726247049', 'orarr': ['MKT', 'LMT', 'SL-LMT', 'SL-MKT'], 'exarr': ['NSE', 'NIPO', 'BSE', 'BSTAR', 'NFO', 'BFO'], 'values': ['5', '1'], 'mws': {'5': [], '1': [{'exch': 'NSE', 'token': '1333', 'tsym': 'HDFCBANK-EQ', 'instname': 'EQ', 'pp': '2', 'ls': '1', 'ti': '0.05'}, {'exch': 'NSE', 'token': '2885', 'tsym': 'RELIANCE-EQ', 'instname': 'EQ', 'pp': '2', 'ls': '1', 'ti': '0.05'}, {'exch': 'NSE', 'token': '14233', 'tsym': 'HDFCSML250-EQ', 'instname': 'EQ', 'pp': '2', 'ls': '1', 'ti': '0.01'}]}, 'brkname': 'FINV', 'dmsg': '', 'lastaccesstime': '1712469578'}

# %%
# ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')
session_token = open('session_token.txt','r').read()
print(len(session_token))
api.set_session(user, pwd, session_token)
api.get_limits()
# Out:
# 64
# {'request_time': '11:29:38 07-04-2024',
#  'stat': 'Ok',
#  'prfname': 'SHOONYA',
#  'cash': '5804.87',
#  'payin': '1374554.00',
#  'payout': '0.00',
#  'brkcollamt': '0.00',
#  'unclearedcash': '0.00',
#  'aux_daycash': '0.00',
#  'aux_brkcollamt': '0.00',
#  'aux_unclearedcash': '0.00',
#  'daycash': '0.00',
#  'turnoverlmt': '999999999999.00',
#  'pendordvallmt': '999999999999.00',
#  'remarks_amt': '0.00',
#  'blk_amt': '0.00'}

# %%
def get_expiry_dates(exchange, symbol):
    import re
    import datetime
    sd = api.searchscrip(exchange, symbol)
    sd = (sd['values'])
    tsym_values = [Symbol['tsym'] for Symbol in sd]
    dates = [re.search(r'\d+[A-Z]{3}\d+', tsym).group() for tsym in tsym_values]
    formatted_dates = [datetime.datetime.strptime(date, '%d%b%y').strftime('%Y-%m-%d') for date in dates]
    sorted_formatted_dates = sorted(formatted_dates)
    expiry_dates = sorted_formatted_dates
#     sorted_dates = [datetime.datetime.strptime(date, '%Y-%m-%d').strftime('%d%b%y').upper() for date in sorted_formatted_dates]
#     expiry_dates = sorted_dates
    return expiry_dates

expiry_date = get_expiry_dates('NFO', index)[0]
print(expiry_date)
# Out:
# 2024-04-10

# %%
import pandas as pd
from datetime import datetime,date
symbolDf = pd.read_csv('https://api.shoonya.com/NFO_symbols.txt.zip')
symbolDf['Expiry'] = pd.to_datetime(symbolDf['Expiry']).apply(lambda x: x.date())   
symbolDf
# Out:
#       Exchange   Token  LotSize     Symbol           TradingSymbol  \
# 0          NFO  142020      900  ZYDUSLIFE   ZYDUSLIFE30MAY24P1280
# 1          NFO  142019      900  ZYDUSLIFE   ZYDUSLIFE30MAY24C1280
# 2          NFO  142018      900  ZYDUSLIFE   ZYDUSLIFE30MAY24P1240
# 3          NFO  142017      900  ZYDUSLIFE   ZYDUSLIFE30MAY24C1240
# 4          NFO  142016      900  ZYDUSLIFE   ZYDUSLIFE30MAY24P1200
# ...        ...     ...      ...        ...                     ...
# 78232      NFO   35004       50      NIFTY           NIFTY27JUN24F
# 78233      NFO   35003       15  BANKNIFTY  BANKNIFTY10APR24P41800
# 78234      NFO   35002       15  BANKNIFTY  BANKNIFTY10APR24C41800
# 78235      NFO   35001       15  BANKNIFTY  BANKNIFTY10APR24P54100
# 78236      NFO   35000       15  BANKNIFTY  BANKNIFTY10APR24C54100
#
#            Expiry Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 0      2024-05-30     OPTSTK         PE      1280.00      0.05          NaN
# 1      2024-05-30     OPTSTK         CE      1280.00      0.05          NaN
# 2      2024-05-30     OPTSTK         PE      1240.00      0.05          NaN
# 3      2024-05-30     OPTSTK         CE      1240.00      0.05          NaN
# 4      2024-05-30     OPTSTK         PE      1200.00      0.05          NaN
# ...           ...        ...        ...          ...       ...          ...
# 78232  2024-06-27     FUTIDX         XX        -0.01      0.05          NaN
# 78233  2024-04-10     OPTIDX         PE     41800.00      0.05          NaN
# 78234  2024-04-10     OPTIDX         CE     41800.00      0.05          NaN
# 78235  2024-04-10     OPTIDX         PE     54100.00      0.05          NaN
# 78236  2024-04-10     OPTIDX         CE     54100.00      0.05          NaN
#
# [78237 rows x 11 columns]

# %%
date_object = datetime.strptime(expiry_date, "%Y-%m-%d").date()

ocdf = symbolDf[(symbolDf.Symbol == index) & (symbolDf.Expiry == date_object)]
ocdf
# Out:
#       Exchange  Token  LotSize     Symbol           TradingSymbol      Expiry  \
# 66689      NFO  46819       15  BANKNIFTY  BANKNIFTY10APR24P63000  2024-04-10
# 66691      NFO  46817       15  BANKNIFTY  BANKNIFTY10APR24C63000  2024-04-10
# 66697      NFO  46811       15  BANKNIFTY  BANKNIFTY10APR24P62500  2024-04-10
# 66698      NFO  46810       15  BANKNIFTY  BANKNIFTY10APR24C62500  2024-04-10
# 66700      NFO  46808       15  BANKNIFTY  BANKNIFTY10APR24P62000  2024-04-10
# ...        ...    ...      ...        ...                     ...         ...
# 78228      NFO  35008       15  BANKNIFTY  BANKNIFTY10APR24C40800  2024-04-10
# 78233      NFO  35003       15  BANKNIFTY  BANKNIFTY10APR24P41800  2024-04-10
# 78234      NFO  35002       15  BANKNIFTY  BANKNIFTY10APR24C41800  2024-04-10
# 78235      NFO  35001       15  BANKNIFTY  BANKNIFTY10APR24P54100  2024-04-10
# 78236      NFO  35000       15  BANKNIFTY  BANKNIFTY10APR24C54100  2024-04-10
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 66689     OPTIDX         PE      63000.0      0.05          NaN
# 66691     OPTIDX         CE      63000.0      0.05          NaN
# 66697     OPTIDX         PE      62500.0      0.05          NaN
# 66698     OPTIDX         CE      62500.0      0.05          NaN
# 66700     OPTIDX         PE      62000.0      0.05          NaN
# ...          ...        ...          ...       ...          ...
# 78228     OPTIDX         CE      40800.0      0.05          NaN
# 78233     OPTIDX         PE      41800.0      0.05          NaN
# 78234     OPTIDX         CE      41800.0      0.05          NaN
# 78235     OPTIDX         PE      54100.0      0.05          NaN
# 78236     OPTIDX         CE      54100.0      0.05          NaN
#
# [350 rows x 11 columns]

# %%
len(ocdf)
# Out:
# 350

# %%
Cedf =ocdf[(ocdf.OptionType == 'CE')& (ocdf['StrikePrice'] > lower_limit) & (ocdf['StrikePrice'] < upper_limit)] 
Cedf
# Out:
#       Exchange  Token  LotSize     Symbol           TradingSymbol      Expiry  \
# 67057      NFO  46451       15  BANKNIFTY  BANKNIFTY10APR24C50900  2024-04-10
# 67062      NFO  46446       15  BANKNIFTY  BANKNIFTY10APR24C50800  2024-04-10
# 67085      NFO  46423       15  BANKNIFTY  BANKNIFTY10APR24C50700  2024-04-10
# 67087      NFO  46421       15  BANKNIFTY  BANKNIFTY10APR24C50600  2024-04-10
# 67184     OPTIDX         CE      48500.0      0.05          NaN
# 67186     OPTIDX         CE      48400.0      0.05          NaN
# 67190     OPTIDX         CE      48300.0      0.05          NaN
# 67192     OPTIDX         CE      48200.0      0.05          NaN
# 67194     OPTIDX         CE      48100.0      0.05          NaN
# 67198     OPTIDX         CE      48000.0      0.05          NaN
# 67200     OPTIDX         CE      47900.0      0.05          NaN
# 67202     OPTIDX         CE      47800.0      0.05          NaN
# 67204     OPTIDX         CE      47700.0      0.05          NaN
# 67206     OPTIDX         CE      47600.0      0.05          NaN
# 67208     OPTIDX         CE      47500.0      0.05          NaN
# 67210     OPTIDX         CE      47400.0      0.05          NaN
# 67212     OPTIDX         CE      47300.0      0.05          NaN
# 67214     OPTIDX         CE      47200.0      0.05          NaN
# 67216     OPTIDX         CE      47100.0      0.05          NaN
# 67218     OPTIDX         CE      47000.0      0.05          NaN
# 67220     OPTIDX         CE      46900.0      0.05          NaN
# 67222     OPTIDX         CE      46800.0      0.05          NaN
# 67224     OPTIDX         CE      46700.0      0.05          NaN
# 67226     OPTIDX         CE      46600.0      0.05          NaN
# 67228     OPTIDX         CE      46500.0      0.05          NaN
# 67240     OPTIDX         CE      46400.0      0.05          NaN
# 67242     OPTIDX         CE      46300.0      0.05          NaN
# 67246     OPTIDX         CE      46200.0      0.05          NaN
# 67248     OPTIDX         CE      46100.0      0.05          NaN
# 67250     OPTIDX         CE      46000.0      0.05          NaN
# 67253     OPTIDX         CE      45900.0      0.05          NaN
# 67255     OPTIDX         CE      45800.0      0.05          NaN
# 67257     OPTIDX         CE      45700.0      0.05          NaN
# 67261     OPTIDX         CE      45600.0      0.05          NaN
# 67271     OPTIDX         CE      45500.0      0.05          NaN

# %%
Pedf =ocdf[(ocdf.OptionType == 'PE') & (ocdf['StrikePrice'] > lower_limit) & (ocdf['StrikePrice'] < upper_limit)] 
Pedf
# Out:
#       Exchange  Token  LotSize     Symbol           TradingSymbol      Expiry  \
# 67056      NFO  46452       15  BANKNIFTY  BANKNIFTY10APR24P50900  2024-04-10
# 67061      NFO  46447       15  BANKNIFTY  BANKNIFTY10APR24P50800  2024-04-10
# 67084      NFO  46424       15  BANKNIFTY  BANKNIFTY10APR24P50700  2024-04-10
# 67086      NFO  46422       15  BANKNIFTY  BANKNIFTY10APR24P50600  2024-04-10
# 67088      NFO  46420       15  BANKNIFTY  BANKNIFTY10APR24P50500  2024-04-10
# 67091      NFO  46417       15  BANKNIFTY  BANKNIFTY10APR24P50400  2024-04-10
# 67095      NFO  46413       15  BANKNIFTY  BANKNIFTY10APR24P50300  2024-04-10
# 67107      NFO  46401       15  BANKNIFTY  BANKNIFTY10APR24P50200  2024-04-10
# 67109      NFO  46399       15  BANKNIFTY  BANKNIFTY10APR24P50100  2024-04-10
# 67113      NFO  46395       15  BANKNIFTY  BANKNIFTY10APR24P50000  2024-04-10
# 67115      NFO  46393       15  BANKNIFTY  BANKNIFTY10APR24P49900  2024-04-10
# 67123      NFO  46385       15  BANKNIFTY  BANKNIFTY10APR24P49800  2024-04-10
# 67229      NFO  46279       15  BANKNIFTY  BANKNIFTY10APR24P46400  2024-04-10
# 67241      NFO  46267       15  BANKNIFTY  BANKNIFTY10APR24P46300  2024-04-10
# 67243      NFO  46265       15  BANKNIFTY  BANKNIFTY10APR24P46200  2024-04-10
# 67247      NFO  46261       15  BANKNIFTY  BANKNIFTY10APR24P46100  2024-04-10
# 67249      NFO  46259       15  BANKNIFTY  BANKNIFTY10APR24P46000  2024-04-10
# 67251      NFO  46257       15  BANKNIFTY  BANKNIFTY10APR24P45900  2024-04-10
# 67254      NFO  46254       15  BANKNIFTY  BANKNIFTY10APR24P45800  2024-04-10
# 67256      NFO  46252       15  BANKNIFTY  BANKNIFTY10APR24P45700  2024-04-10
# 67260      NFO  46248       15  BANKNIFTY  BANKNIFTY10APR24P45600  2024-04-10
# 67268      NFO  46240       15  BANKNIFTY  BANKNIFTY10APR24P45500  2024-04-10
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 67056     OPTIDX         PE      50900.0      0.05          NaN
# 67061     OPTIDX         PE      50800.0      0.05          NaN
# 67084     OPTIDX         PE      50700.0      0.05          NaN
# 67086     OPTIDX         PE      50600.0      0.05          NaN
# 67088     OPTIDX         PE      50500.0      0.05          NaN
# 67091     OPTIDX         PE      50400.0      0.05          NaN
# 67095     OPTIDX         PE      50300.0      0.05          NaN
# 67107     OPTIDX         PE      50200.0      0.05          NaN
# 67109     OPTIDX         PE      50100.0      0.05          NaN
# 67113     OPTIDX         PE      50000.0      0.05          NaN
# 67115     OPTIDX         PE      49900.0      0.05          NaN
# 67123     OPTIDX         PE      49800.0      0.05          NaN
# 67127     OPTIDX         PE      49700.0      0.05          NaN
# 67129     OPTIDX         PE      49600.0      0.05          NaN
# 67131     OPTIDX         PE      49500.0      0.05          NaN
# 67133     OPTIDX         PE      49400.0      0.05          NaN
# 67139     OPTIDX         PE      49300.0      0.05          NaN
# 67159     OPTIDX         PE      49200.0      0.05          NaN
# 67161     OPTIDX         PE      49100.0      0.05          NaN
# 67163     OPTIDX         PE      49000.0      0.05          NaN
# 67169     OPTIDX         PE      48900.0      0.05          NaN
# 67171     OPTIDX         PE      48800.0      0.05          NaN
# 67177     OPTIDX         PE      48700.0      0.05          NaN
# 67179     OPTIDX         PE      48600.0      0.05          NaN
# 67183     OPTIDX         PE      48500.0      0.05          NaN
# 67185     OPTIDX         PE      48400.0      0.05          NaN
# 67187     OPTIDX         PE      48300.0      0.05          NaN
# 67191     OPTIDX         PE      48200.0      0.05          NaN
# 67193     OPTIDX         PE      48100.0      0.05          NaN
# 67195     OPTIDX         PE      48000.0      0.05          NaN
# 67199     OPTIDX         PE      47900.0      0.05          NaN
# 67201     OPTIDX         PE      47800.0      0.05          NaN
# 67203     OPTIDX         PE      47700.0      0.05          NaN
# 67205     OPTIDX         PE      47600.0      0.05          NaN
# 67207     OPTIDX         PE      47500.0      0.05          NaN
# 67209     OPTIDX         PE      47400.0      0.05          NaN
# 67211     OPTIDX         PE      47300.0      0.05          NaN
# 67213     OPTIDX         PE      47200.0      0.05          NaN
# 67215     OPTIDX         PE      47100.0      0.05          NaN
# 67217     OPTIDX         PE      47000.0      0.05          NaN
# 67219     OPTIDX         PE      46900.0      0.05          NaN
# 67221     OPTIDX         PE      46800.0      0.05          NaN
# 67223     OPTIDX         PE      46700.0      0.05          NaN
# 67225     OPTIDX         PE      46600.0      0.05          NaN
# 67227     OPTIDX         PE      46500.0      0.05          NaN
# 67229     OPTIDX         PE      46400.0      0.05          NaN
# 67241     OPTIDX         PE      46300.0      0.05          NaN
# 67243     OPTIDX         PE      46200.0      0.05          NaN
# 67247     OPTIDX         PE      46100.0      0.05          NaN
# 67249     OPTIDX         PE      46000.0      0.05          NaN
# 67251     OPTIDX         PE      45900.0      0.05          NaN
# 67254     OPTIDX         PE      45800.0      0.05          NaN
# 67256     OPTIDX         PE      45700.0      0.05          NaN
# 67260     OPTIDX         PE      45600.0      0.05          NaN
# 67268     OPTIDX         PE      45500.0      0.05          NaN

# %%
expiry_date
from datetime import datetime
date_obj = datetime.strptime(expiry_date, "%Y-%m-%d")
today = datetime.now()
diff = (date_obj - today).days
print(diff)
# Out:
# 2

# %%
sell_premium = {
    "MIDCPNIFTY":[15,15,20,25,30],
    "FINNIFTY":[25,30,35,40,45],
    "NIFTY":[25,30,35,40,45],
    "BANKNIFTY": [50, 60,70,80,90,100],
    "SENSEX":[70,80,100,120,140]
}

# %%
buy_premium = {
    "MIDCPNIFTY":[2,2,3,3,3],
    "FINNIFTY":[3,4,4,5,5],
    "NIFTY":[3,4,4,5,5],
    "BANKNIFTY": [5,10,10,15,15],
    "SENSEX":[5,10,15,15,15]
}

# %%
ltp1 = buy_premium[index][diff]
ltp = sell_premium[index][diff]

print(ltp1)
print(ltp)
strikeList = []
for i in Cedf.index:
    strikeInfo = Cedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
    
strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf1['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
ce_buy = strikedf1.iloc[0].tsym
print(ce_buy)

strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
ce_sell = strikedf.iloc[0].tsym
print(ce_sell)
ce_sl = 2*(strikedf.iloc[0].lp)
print(ce_sl)
# Out:
# 10
# 70
# BANKNIFTY10APR24C49900
# BANKNIFTY10APR24C49200
# 144.0

# %%
ltp = buy_premium[index][diff]
ltp1 = sell_premium[index][diff]

print(ltp)
print(ltp1)

strikeList = []
for i in Pedf.index:
    strikeInfo = Pedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
pe_buy = strikedf.iloc[0].tsym
print(pe_buy)

strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
pe_sell = strikedf1.iloc[0].tsym
print(pe_sell)
pe_sl = 2*(strikedf1.iloc[0].lp)
print(pe_sl)
# Out:
# 10
# 70
# BANKNIFTY10APR24P46100
# BANKNIFTY10APR24P47600
# 132.4

# %%
# ltp = sell_premium[index][diff]
# print(ltp)

# strikeList = []
# for i in Cedf.index:
#     strikeInfo = Cedf.loc[i]
#     res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
#     res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
#     strikeList.append(res)
# strikedf = pd.DataFrame(strikeList)
# strikedf.sort_values(by = 'lp',inplace = True)
# strikedf['diff'] = abs(strikedf['lp'] - ltp)
# strikedf.sort_values(by = 'diff',inplace = True)
# ce_sell = strikedf.iloc[0].tsym

# %%
# ltp = sell_premium[index][diff]
# print(ltp)

# strikeList = []
# for i in Pedf.index:
#     strikeInfo = Pedf.loc[i]
#     res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
#     res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
#     strikeList.append(res)
# strikedf = pd.DataFrame(strikeList)
# strikedf.sort_values(by = 'lp',inplace = True)
# strikedf['diff'] = abs(strikedf['lp'] - ltp)
# strikedf.sort_values(by = 'diff',inplace = True)
# pe_sell = strikedf.iloc[0].tsym

# %%
print(ce_buy)
print(pe_buy)
print(ce_sell)
print(pe_sell)
# Out:
# BANKNIFTY10APR24C49900
# BANKNIFTY10APR24P46100
# BANKNIFTY10APR24C49200
# BANKNIFTY10APR24P47600

# %%
import re

def get_new_strike(original_string, change):
    import re
    match = re.search(r'\d+$', original_string)

    if match:
        # Extracted number
        number = int(match.group())

        # Add 100 to the number
        new_number = number + change

        # Replace the old number with the new number in the original string
        new_string = original_string[:match.start()] + str(new_number)
        
        print("Original string:", original_string)
        print("New string:", new_string)
        return new_string        
    else:
        print("Strike not in proper format")

# %%
# call buy leg
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24040600013366'

# %%
# put buy leg
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24040600013367'

# %%
# call sell leg
ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24040600013368'

# %%
# put sell leg
ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24040600013369'

# %%
# call sl order
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']

# %%
# put sl order
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']

# %%
print(ce_sl_orderid)
print(pe_sl_orderid)
# Out:
# 24040600013370
# 24040600013371

# %%
# # call adj1
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -100)
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # call adj2
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -100)
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # call adj3
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -100)
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # call adj4
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -100)
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']

# %%
# # put adj1
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, 100)
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']

# %%
# # put adj2
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, 100)
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']

# %%
# # put adj3
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, 100)
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']

# %%
# # put adj4
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, 100)
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='C',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']
