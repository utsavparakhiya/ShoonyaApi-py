# %%
indices_array = ['BANKNIFTY', 'NIFTY', 'FINNIFTY', 'MIDCPNIFTY', 'SENSEX']
indices_lot_size = [15, 50, 40, 75, 10]
changes_in_strike = [100, 50, 50, 25, 100]
sensex_expiry_date = '2024-05-03'

# %%
from NorenRestApiPy.NorenApi import  NorenApi

class ShoonyaApiPy(NorenApi):
    def __init__(self):
        NorenApi.__init__(self, host='https://api.shoonya.com/NorenWClientTP/', websocket='wss://api.shoonya.com/NorenWSTP/')        
        global api
        api = self

# %%
import pyotp

api = ShoonyaApiPy()

# %%
id = 0
lots = 2
lower_limit = 46800.00
upper_limit = 50300.00

index = indices_array[id]
lot_size = indices_lot_size[id]

# %%
user = "FA267228"
pwd = "Meet@1811"
vc = "FA267228_U"
app_key = "6ebfa36708493ccaed011fdd2ebe2298"
token = "Q7USK6X664V5544L5NB45HM3N7UU5K4A"

# %%
api = ShoonyaApiPy()
ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')

with open('session_token.txt','w') as file:
    file.write(ret['susertoken'])
print(ret)
# Out:
# {'request_time': '22:13:48 29-04-2024', 'actid': 'FA267228', 'access_type': ['WEB', 'TT', 'MOB', 'API'], 'uname': 'PUSHPABEN ARVINDBHAI VARSADA', 'prarr': [{'prd': 'C', 's_prdt_ali': 'CNC', 'exch': ['NSE', 'BSE', 'NIPO', 'BSTAR']}, {'prd': 'M', 's_prdt_ali': 'NRML', 'exch': ['NFO', 'BFO', 'CDS', 'BCD', 'MCX']}, {'prd': 'I', 's_prdt_ali': 'MIS', 'exch': ['NSE', 'BSE', 'NFO', 'BFO', 'CDS', 'BCD', 'MCX']}, {'prd': 'H', 's_prdt_ali': 'CO', 'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']}, {'prd': 'B', 's_prdt_ali': 'BO', 'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']}], 'exch_prd': [{'exch': 'NSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'NIPO', 'prds': ['C']}, {'exch': 'NFO', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'CDS', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'BSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'BCD', 'prds': ['M', 'I']}, {'exch': 'MCX', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'BSTAR', 'prds': ['C']}, {'exch': 'BFO', 'prds': ['M', 'I']}], 'stat': 'Ok', 'susertoken': '5a0010d071e2423737f6795ae0b374c94dc4da98cf726b56c62a31177a7b5277', 'email': 'meetvarsada18@gmail.com', 'uid': 'FA267228', 'brnchid': 'HO', 'totp_set': '1', 'm_num': '8487944244', 'orarr': ['MKT', 'LMT', 'SL-LMT', 'SL-MKT'], 'exarr': ['NSE', 'NIPO', 'NFO', 'CDS', 'BSE', 'BCD', 'MCX', 'BSTAR', 'BFO'], 'values': ['1'], 'mws': {'1': [{'exch': 'NFO', 'token': '49551', 'tsym': 'BANKNIFTY30APR24C48600', 'dname': 'BANKNIFTY 30APR24 48600 CE ', 'instname': 'OPTIDX', 'pp': '2', 'ls': '15', 'ti': '0.05', 'optt': 'CE'}, {'exch': 'NFO', 'token': '49532', 'tsym': 'BANKNIFTY30APR24P48200', 'dname': 'BANKNIFTY 30APR24 48200 PE ', 'instname': 'OPTIDX', 'pp': '2', 'ls': '15', 'ti': '0.05', 'optt': 'PE'}]}, 'brkname': 'FINV', 'dmsg': '', 'lastaccesstime': '1714409028'}

# %%
# ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')
session_token = open('session_token.txt','r').read()
print(len(session_token))
api.set_session(user, pwd, session_token)
api.get_limits()
# Out:
# 64
# {'request_time': '22:13:48 29-04-2024',
#  'stat': 'Ok',
#  'prfname': 'SHOONYA',
#  'cash': '500100.00',
#  'payin': '0.00',
#  'payout': '0.00',
#  'brkcollamt': '0.00',
#  'unclearedcash': '0.00',
#  'aux_daycash': '0.00',
#  'aux_brkcollamt': '0.00',
#  'aux_unclearedcash': '0.00',
#  'daycash': '0.00',
#  'turnoverlmt': '999999999999.00',
#  'pendordvallmt': '999999999999.00',
#  'remarks_amt': '0.00',
#  'turnover': '11654066.25',
#  'marginused': '2129.88',
#  'peak_mar': '445519.52',
#  'margincurper': '0.43',
#  'premium': '2091.75',
#  'brokerage': '38.13',
#  'premium_d_m': '2091.75',
#  'brkage_d_m': '38.13',
#  'blk_amt': '0.00',
#  'mr_der_u': '20.92',
#  'mr_der_a': '350767.24'}

# %%
import pandas as pd
from datetime import datetime,date
nfo_url = 'https://api.shoonya.com/NFO_symbols.txt.zip'
bfo_url = 'https://api.shoonya.com/BFO_symbols.txt.zip'
symbolDf = pd.read_csv(bfo_url if index == 'SENSEX' else nfo_url)
symbolDf['Expiry'] = pd.to_datetime(symbolDf['Expiry']).apply(lambda x: x.date())   
symbolDf
# Out:
#       Exchange   Token  LotSize     Symbol           TradingSymbol  \
# 0          NFO  146751      900  ZYDUSLIFE   ZYDUSLIFE25JUL24P1440
# 1          NFO  146750      900  ZYDUSLIFE   ZYDUSLIFE25JUL24C1440
# 2          NFO  146749      900  ZYDUSLIFE   ZYDUSLIFE25JUL24P1400
# 3          NFO  146748      900  ZYDUSLIFE   ZYDUSLIFE25JUL24C1400
# 4          NFO  146747      900  ZYDUSLIFE   ZYDUSLIFE25JUL24P1360
# ...        ...     ...      ...        ...                     ...
# 77341      NFO   35004       25      NIFTY           NIFTY27JUN24F
# 77342      NFO   35003       15  BANKNIFTY  BANKNIFTY15MAY24P42600
# 77343      NFO   35002       15  BANKNIFTY  BANKNIFTY15MAY24C42600
# 77344      NFO   35001       15  BANKNIFTY  BANKNIFTY15MAY24P33500
# 77345      NFO   35000       15  BANKNIFTY  BANKNIFTY15MAY24C33500
#
#            Expiry Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 0      2024-07-25     OPTSTK         PE      1440.00      0.05          NaN
# 1      2024-07-25     OPTSTK         CE      1440.00      0.05          NaN
# 2      2024-07-25     OPTSTK         PE      1400.00      0.05          NaN
# 3      2024-07-25     OPTSTK         CE      1400.00      0.05          NaN
# 4      2024-07-25     OPTSTK         PE      1360.00      0.05          NaN
# ...           ...        ...        ...          ...       ...          ...
# 77341  2024-06-27     FUTIDX         XX        -0.01      0.05          NaN
# 77342  2024-05-15     OPTIDX         PE     42600.00      0.05          NaN
# 77343  2024-05-15     OPTIDX         CE     42600.00      0.05          NaN
# 77344  2024-05-15     OPTIDX         PE     33500.00      0.05          NaN
# 77345  2024-05-15     OPTIDX         CE     33500.00      0.05          NaN
#
# [77346 rows x 11 columns]

# %%
def get_expiry_dates(exchange, symbol):
    import re
    import datetime
    sd = api.searchscrip(exchange, symbol)
    sd = (sd['values'])
    tsym_values = [Symbol['tsym'] for Symbol in sd]
    dates = [re.search(r'\d+[A-Z]{3}\d+', tsym).group() for tsym in tsym_values]
    formatted_dates = [datetime.datetime.strptime(date, '%d%b%y').strftime('%Y-%m-%d') for date in dates]
    sorted_formatted_dates = sorted(formatted_dates)
    expiry_dates = sorted_formatted_dates
#     sorted_dates = [datetime.datetime.strptime(date, '%Y-%m-%d').strftime('%d%b%y').upper() for date in sorted_formatted_dates]
#     expiry_dates = sorted_dates
    return expiry_dates

expiry_date = sensex_expiry_date if index == 'SENSEX' else get_expiry_dates('BFO' if index == 'SENSEX' else 'NFO', index)[0]
print(expiry_date)
# Out:
# 2024-04-30

# %%
date_object = datetime.strptime(expiry_date, "%Y-%m-%d").date()

ocdf = symbolDf[(symbolDf.Symbol == ('BSXOPT' if index == 'SENSEX' else index)) & (symbolDf.Expiry == date_object)]
ocdf
# Out:
#       Exchange  Token  LotSize     Symbol           TradingSymbol      Expiry  \
# 57534      NFO  63891       15  BANKNIFTY  BANKNIFTY30APR24P53100  2024-04-30
# 57535      NFO  63890       15  BANKNIFTY  BANKNIFTY30APR24C53100  2024-04-30
# 66505      NFO  50783       15  BANKNIFTY  BANKNIFTY30APR24P61500  2024-04-30
# 66510      NFO  50778       15  BANKNIFTY  BANKNIFTY30APR24C61500  2024-04-30
# 66511      NFO  50777       15  BANKNIFTY  BANKNIFTY30APR24P61000  2024-04-30
# ...        ...    ...      ...        ...                     ...         ...
# 77231      NFO  35120       15  BANKNIFTY  BANKNIFTY30APR24P31500  2024-04-30
# 77233      NFO  35118       15  BANKNIFTY  BANKNIFTY30APR24C31500  2024-04-30
# 77273      NFO  35072       15  BANKNIFTY  BANKNIFTY30APR24P52400  2024-04-30
# 77274      NFO  35071       15  BANKNIFTY  BANKNIFTY30APR24C52400  2024-04-30
# 77303      NFO  35042       15  BANKNIFTY  BANKNIFTY30APR24C52800  2024-04-30
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 57534     OPTIDX         PE      53100.0      0.05          NaN
# 57535     OPTIDX         CE      53100.0      0.05          NaN
# 66505     OPTIDX         PE      61500.0      0.05          NaN
# 66510     OPTIDX         CE      61500.0      0.05          NaN
# 66511     OPTIDX         PE      61000.0      0.05          NaN
# ...          ...        ...          ...       ...          ...
# 77231     OPTIDX         PE      31500.0      0.05          NaN
# 77233     OPTIDX         CE      31500.0      0.05          NaN
# 77273     OPTIDX         PE      52400.0      0.05          NaN
# 77274     OPTIDX         CE      52400.0      0.05          NaN
# 77303     OPTIDX         CE      52800.0      0.05          NaN
#
# [368 rows x 11 columns]

# %%
# 67279      NFO  49496       15  BANKNIFTY  BANKNIFTY30APR24C47000  2024-04-30
# 67285      NFO  49490       15  BANKNIFTY  BANKNIFTY30APR24C46900  2024-04-30
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 67180     OPTIDX         CE      50200.0      0.05          NaN
# 67182     OPTIDX         CE      50100.0      0.05          NaN
# 67184     OPTIDX         CE      50000.0      0.05          NaN
# 67186     OPTIDX         CE      49900.0      0.05          NaN
# 67188     OPTIDX         CE      49800.0      0.05          NaN
# 67196     OPTIDX         CE      49700.0      0.05          NaN
# 67198     OPTIDX         CE      49600.0      0.05          NaN
# 67200     OPTIDX         CE      49500.0      0.05          NaN
# 67202     OPTIDX         CE      49400.0      0.05          NaN
# 67207     OPTIDX         CE      49300.0      0.05          NaN
# 67213     OPTIDX         CE      49200.0      0.05          NaN
# 67219     OPTIDX         CE      49100.0      0.05          NaN
# 67221     OPTIDX         CE      49000.0      0.05          NaN
# 67225     OPTIDX         CE      48900.0      0.05          NaN
# 67227     OPTIDX         CE      48800.0      0.05          NaN
# 67229     OPTIDX         CE      48700.0      0.05          NaN
# 67232     OPTIDX         CE      48600.0      0.05          NaN
# 67235     OPTIDX         CE      48500.0      0.05          NaN
# 67237     OPTIDX         CE      48400.0      0.05          NaN
# 67244     OPTIDX         CE      48300.0      0.05          NaN
# 67246     OPTIDX         CE      48200.0      0.05          NaN
# 67254     OPTIDX         CE      48100.0      0.05          NaN
# 67256     OPTIDX         CE      48000.0      0.05          NaN
# 67258     OPTIDX         CE      47900.0      0.05          NaN
# 67263     OPTIDX         CE      47800.0      0.05          NaN
# 67265     OPTIDX         CE      47700.0      0.05          NaN
# 67267     OPTIDX         CE      47600.0      0.05          NaN
# 67269     OPTIDX         CE      47500.0      0.05          NaN
# 67271     OPTIDX         CE      47400.0      0.05          NaN
# 67273     OPTIDX         CE      47300.0      0.05          NaN
# 67275     OPTIDX         CE      47200.0      0.05          NaN
# 67277     OPTIDX         CE      47100.0      0.05          NaN
# 67279     OPTIDX         CE      47000.0      0.05          NaN
# 67285     OPTIDX         CE      46900.0      0.05          NaN

# %%
Pedf =ocdf[(ocdf.OptionType == 'PE') & (ocdf['StrikePrice'] > lower_limit) & (ocdf['StrikePrice'] < upper_limit)] 
Pedf
# Out:
#       Exchange  Token  LotSize     Symbol           TradingSymbol      Expiry  \
# 67177      NFO  49608       15  BANKNIFTY  BANKNIFTY30APR24P50200  2024-04-30
# 67181      NFO  49604       15  BANKNIFTY  BANKNIFTY30APR24P50100  2024-04-30
# 67183      NFO  49602       15  BANKNIFTY  BANKNIFTY30APR24P50000  2024-04-30
# 67185      NFO  49600       15  BANKNIFTY  BANKNIFTY30APR24P49900  2024-04-30
# 67187      NFO  49598       15  BANKNIFTY  BANKNIFTY30APR24P49800  2024-04-30
# 67195      NFO  49590       15  BANKNIFTY  BANKNIFTY30APR24P49700  2024-04-30
# 67197      NFO  49588       15  BANKNIFTY  BANKNIFTY30APR24P49600  2024-04-30
# 67199      NFO  49586       15  BANKNIFTY  BANKNIFTY30APR24P49500  2024-04-30
# 67226     OPTIDX         PE      48800.0      0.05          NaN
# 67228     OPTIDX         PE      48700.0      0.05          NaN
# 67231     OPTIDX         PE      48600.0      0.05          NaN
# 67234     OPTIDX         PE      48500.0      0.05          NaN
# 67236     OPTIDX         PE      48400.0      0.05          NaN
# 67241     OPTIDX         PE      48300.0      0.05          NaN
# 67245     OPTIDX         PE      48200.0      0.05          NaN
# 67253     OPTIDX         PE      48100.0      0.05          NaN
# 67255     OPTIDX         PE      48000.0      0.05          NaN
# 67257     OPTIDX         PE      47900.0      0.05          NaN
# 67261     OPTIDX         PE      47800.0      0.05          NaN
# 67264     OPTIDX         PE      47700.0      0.05          NaN
# 67266     OPTIDX         PE      47600.0      0.05          NaN
# 67268     OPTIDX         PE      47500.0      0.05          NaN
# 67270     OPTIDX         PE      47400.0      0.05          NaN
# 67272     OPTIDX         PE      47300.0      0.05          NaN
# 67274     OPTIDX         PE      47200.0      0.05          NaN
# 67276     OPTIDX         PE      47100.0      0.05          NaN
# 67278     OPTIDX         PE      47000.0      0.05          NaN
# 67280     OPTIDX         PE      46900.0      0.05          NaN

# %%
api.get_quotes(exchange='BFO', token='867307')

# %%
api.get_quotes(exchange='NFO', token='67521')
# Out:
# {'request_time': '22:13:52 29-04-2024',
#  'stat': 'Ok',
#  'exch': 'NFO',
#  'tsym': 'ABFRL25JUL24C250',
#  'cname': 'ABFRL JUL 250 CE ',
#  'symname': 'ABFRL',
#  'seg': 'DER',
#  'exd': '25-JUL-2024',
#  'instname': 'OPTSTK',
#  'optt': 'CE',
#  'pp': '2',
#  'ls': '2600',
#  'ti': '0.05',
#  'mult': '1',
#  'lut': '1714394596',
#  'uc': '47.65',
#  'lc': '22.25',
#  'oi': '0',
#  'cutof_all': 'false',
#  'strprc': '250.00',
#  'prcftr_d': '(1 / 1 ) * (1 / 1)',
#  'token': '67521',
#  'lp': '35.20',
#  'c': '35.20',
#  'und_exch': 'NSE',
#  'und_tk': '30108'}

# %%
expiry_date
from datetime import datetime
date_obj = datetime.strptime(expiry_date, "%Y-%m-%d")
today = datetime.now()
diff = (date_obj - today).days
print(diff)
# Out:
# 0

# %%
sell_premium = {
    "MIDCPNIFTY":[15,15,20,25,30,30,30],
    "FINNIFTY":[25,30,35,40,45,45,45],
    "NIFTY":[25,30,35,40,45, 45, 45],
    "BANKNIFTY": [50, 60,70,80,90,100,100,100],
    "SENSEX":[70,80,100,120,140,140,140]
}

# %%
buy_premium = {
    "MIDCPNIFTY":[2,2,3,3,3,3,3],
    "FINNIFTY":[3,4,4,5,5,5,5],
    "NIFTY":[3,4,4,5,5,5,5],
    "BANKNIFTY": [5,10,10,15,15,15,15],
    "SENSEX":[5,10,15,15,15,15,15]
}

# %%
ltp1 = buy_premium[index][diff]
ltp = sell_premium[index][diff]

print(ltp1)
print(ltp)
strikeList = []
for i in Cedf.index:
    strikeInfo = Cedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
    
strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf1['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
ce_buy = strikedf1.iloc[0].tsym
print(ce_buy)

strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
ce_sell = strikedf.iloc[0].tsym
print(ce_sell)
ce_sl = 2*(strikedf.iloc[0].lp)
print(ce_sl)
# Out:
# 5
# 50
# BANKNIFTY30APR24C50200
# BANKNIFTY30APR24C49800
# 109.0

# %%
ltp = buy_premium[index][diff]
ltp1 = sell_premium[index][diff]

print(ltp)
print(ltp1)

strikeList = []
for i in Pedf.index:
    strikeInfo = Pedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
pe_buy = strikedf.iloc[0].tsym
print(pe_buy)

strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
pe_sell = strikedf1.iloc[0].tsym
print(pe_sell)
pe_sl = 2*(strikedf1.iloc[0].lp)
print(pe_sl)
# Out:
# 5
# 50
# BANKNIFTY30APR24P47000
# BANKNIFTY30APR24P48900
# 90.6

# %%
# ltp = sell_premium[index][diff]
# print(ltp)

# strikeList = []
# for i in Cedf.index:
#     strikeInfo = Cedf.loc[i]
#     res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
#     res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
#     strikeList.append(res)
# strikedf = pd.DataFrame(strikeList)
# strikedf.sort_values(by = 'lp',inplace = True)
# strikedf['diff'] = abs(strikedf['lp'] - ltp)
# strikedf.sort_values(by = 'diff',inplace = True)
# ce_sell = strikedf.iloc[0].tsym

# %%
# ltp = sell_premium[index][diff]
# print(ltp)

# strikeList = []
# for i in Pedf.index:
#     strikeInfo = Pedf.loc[i]
#     res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
#     res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
#     strikeList.append(res)
# strikedf = pd.DataFrame(strikeList)
# strikedf.sort_values(by = 'lp',inplace = True)
# strikedf['diff'] = abs(strikedf['lp'] - ltp)
# strikedf.sort_values(by = 'diff',inplace = True)
# pe_sell = strikedf.iloc[0].tsym

# %%
print(ce_buy)
print(pe_buy)
print(ce_sell)
print(pe_sell)
# Out:
# BANKNIFTY30APR24C50200
# BANKNIFTY30APR24P47000
# BANKNIFTY30APR24C49800
# BANKNIFTY30APR24P48900

# %%
import re

def get_new_strike(original_string, change):
    import re
    match = re.search(r'\d+$', original_string)

    if match:
        # Extracted number
        number = int(match.group())

        # Add 100 to the number
        new_number = number + change

        # Replace the old number with the new number in the original string
        new_string = original_string[:match.start()] + str(new_number)
        
        print("Original string:", original_string)
        print("New string:", new_string)
        return new_string        
    else:
        print("Strike not in proper format")

# %%
# call buy leg
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24042901235556'

# %%
# put buy leg
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24042901235558'

# %%
# call sell leg
ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24042901235560'

# %%
# put sell leg
ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24042901235561'

# %%
# call sl order
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']

# %%
# put sl order
ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']

# %%
print(ce_sl_orderid)
print(pe_sl_orderid)
# Out:
# 24042901235562
# 24042901235563

# %%
# call adj1
ret = api.cancel_order(orderno=ce_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
ce_sell = new_ce_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:02 14-04-2024","stat":"Ok","result":"24041300004639"}
# Original string: BANKNIFTY16APR24C49200
# New string: BANKNIFTY16APR24C49100

# %%
# call adj2
ret = api.cancel_order(orderno=ce_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
ce_sell = new_ce_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:03 14-04-2024","stat":"Ok","result":"24041300004643"}
# Original string: BANKNIFTY16APR24C49100
# New string: BANKNIFTY16APR24C49000

# %%
# call adj3
ret = api.cancel_order(orderno=ce_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
ce_sell = new_ce_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:04 14-04-2024","stat":"Ok","result":"24041300004646"}
# Original string: BANKNIFTY16APR24C49000
# New string: BANKNIFTY16APR24C48900

# %%
# call adj4
ret = api.cancel_order(orderno=ce_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
ce_sell = new_ce_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:04 14-04-2024","stat":"Ok","result":"24041300004649"}
# Original string: BANKNIFTY16APR24C48900
# New string: BANKNIFTY16APR24C48800

# %%
# put adj1
ret = api.cancel_order(orderno=pe_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
pe_sell = new_pe_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:05 14-04-2024","stat":"Ok","result":"24041300004640"}
# Original string: BANKNIFTY16APR24P48100
# New string: BANKNIFTY16APR24P48200

# %%
# put adj2
ret = api.cancel_order(orderno=pe_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
pe_sell = new_pe_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:06 14-04-2024","stat":"Ok","result":"24041300004655"}
# Original string: BANKNIFTY16APR24P48200
# New string: BANKNIFTY16APR24P48300

# %%
# put adj3
ret = api.cancel_order(orderno=pe_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
pe_sell = new_pe_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:07 14-04-2024","stat":"Ok","result":"24041300004658"}
# Original string: BANKNIFTY16APR24P48300
# New string: BANKNIFTY16APR24P48400

# %%
# put adj4
ret = api.cancel_order(orderno=pe_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
pe_sell = new_pe_strike

ret = api.place_order(buy_or_sell='S', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='C',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:07 14-04-2024","stat":"Ok","result":"24041300004661"}
# Original string: BANKNIFTY16APR24P48400
# New string: BANKNIFTY16APR24P48500
