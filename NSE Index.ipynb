# %%
sell_premium = {
    "MIDCPNIFTY":[15,15,20,25,30,30,30],
    "FINNIFTY":[25,30,35,40,45,45,45],
    "NIFTY":[25,30,35,40,45, 45, 45],
    "BANKNIFTY": [50, 60,70,80,90,100,100,100],
    "SENSEX":[70,80,100,120,140,140,140]
}

buy_premium = {
    "MIDCPNIFTY":[2,2,3,3,3,3,3],
    "FINNIFTY":[3,4,4,5,5,5,5],
    "NIFTY":[3,4,4,5,5,5,5],
    "BANKNIFTY": [5,10,10,15,15,15,15],
    "SENSEX":[5,10,15,15,15,15,15]
}

indices_array = ['BANKNIFTY', 'NIFTY', 'FINNIFTY', 'MIDCPNIFTY', 'SENSEX']
indices_lot_size = [15, 25, 40, 75, 10]
changes_in_strike = [100, 50, 50, 25, 100]

index_lower_limit = [46900.00, 21750.00, 46800.00, 46800.00, 46800.00]
index_upper_limit = [50900.00, 23250.00, 50300.00, 50300.00, 50300.00]

expiry_date = '2024-05-09'

id = 1
lots = 5
diff = 3

# %%
from NorenRestApiPy.NorenApi import  NorenApi

class ShoonyaApiPy(NorenApi):
    def __init__(self):
        NorenApi.__init__(self, host='https://api.shoonya.com/NorenWClientTP/', websocket='wss://api.shoonya.com/NorenWSTP/')        
        global api
        api = self

# %%
import pyotp

api = ShoonyaApiPy()

# %%
lower_limit = index_lower_limit[id]
upper_limit = index_upper_limit[id]

index = indices_array[id]
lot_size = indices_lot_size[id]

# %%
user = "FA267228"
pwd = "Meet@1811"
vc = "FA267228_U"
app_key = "6ebfa36708493ccaed011fdd2ebe2298"
token = "Q7USK6X664V5544L5NB45HM3N7UU5K4A"

# %%
api = ShoonyaApiPy()
ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')

with open('session_token.txt','w') as file:
    file.write(ret['susertoken'])
print(ret)
# Out:
# {'request_time': '09:47:26 05-05-2024', 'actid': 'FA267228', 'access_type': ['WEB', 'TT', 'MOB', 'API'], 'uname': 'PUSHPABEN ARVINDBHAI VARSADA', 'prarr': [{'prd': 'C', 's_prdt_ali': 'CNC', 'exch': ['NSE', 'BSE', 'NIPO', 'BSTAR']}, {'prd': 'M', 's_prdt_ali': 'NRML', 'exch': ['NFO', 'BFO', 'CDS', 'BCD', 'MCX']}, {'prd': 'I', 's_prdt_ali': 'MIS', 'exch': ['NSE', 'BSE', 'NFO', 'BFO', 'CDS', 'BCD', 'MCX']}, {'prd': 'H', 's_prdt_ali': 'CO', 'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']}, {'prd': 'B', 's_prdt_ali': 'BO', 'exch': ['NSE', 'NFO', 'CDS', 'MCX', 'BSE']}], 'exch_prd': [{'exch': 'NSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'NIPO', 'prds': ['C']}, {'exch': 'NFO', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'CDS', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'BSE', 'prds': ['C', 'I', 'H', 'B']}, {'exch': 'BCD', 'prds': ['M', 'I']}, {'exch': 'MCX', 'prds': ['M', 'I', 'H', 'B']}, {'exch': 'BSTAR', 'prds': ['C']}, {'exch': 'BFO', 'prds': ['M', 'I']}], 'stat': 'Ok', 'susertoken': '96e5a7a8a61e5dcecf3f16de0be85781d77d948c5c939be6f5b3c6dac7251f86', 'email': 'meetvarsada18@gmail.com', 'uid': 'FA267228', 'brnchid': 'HO', 'totp_set': '1', 'm_num': '8487944244', 'orarr': ['MKT', 'LMT', 'SL-LMT', 'SL-MKT'], 'exarr': ['NSE', 'NIPO', 'NFO', 'CDS', 'BSE', 'BCD', 'MCX', 'BSTAR', 'BFO'], 'values': ['1'], 'mws': {'1': [{'exch': 'NFO', 'token': '43851', 'tsym': 'BANKNIFTY08MAY24C49800', 'weekly': 'W2', 'dname': 'BANKNIFTY 08MAY24 49800 CE ', 'instname': 'OPTIDX', 'pp': '2', 'ls': '15', 'ti': '0.05', 'optt': 'CE'}, {'exch': 'NFO', 'token': '43793', 'tsym': 'BANKNIFTY08MAY24P49400', 'weekly': 'W2', 'dname': 'BANKNIFTY 08MAY24 49400 PE ', 'instname': 'OPTIDX', 'pp': '2', 'ls': '15', 'ti': '0.05', 'optt': 'PE'}]}, 'brkname': 'FINV', 'dmsg': '', 'lastaccesstime': '1714882646'}

# %%
# ret = api.login(userid=user, password=pwd, twoFA=pyotp.TOTP(token).now(), vendor_code=vc, api_secret=app_key, imei='abc1234')
session_token = open('session_token.txt','r').read()
print(len(session_token))
api.set_session(user, pwd, session_token)
api.get_limits()
# Out:
# 64
# {'request_time': '09:47:26 05-05-2024',
#  'stat': 'Ok',
#  'prfname': 'SHOONYA',
#  'cash': '984824.73',
#  'payin': '0.00',
#  'payout': '0.00',
#  'brkcollamt': '0.00',
#  'unclearedcash': '0.00',
#  'aux_daycash': '0.00',
#  'aux_brkcollamt': '0.00',
#  'aux_unclearedcash': '0.00',
#  'daycash': '0.00',
#  'turnoverlmt': '999999999999.00',
#  'pendordvallmt': '999999999999.00',
#  'remarks_amt': '0.00',
#  'remarks_text': '',
#  'blk_amt': '0.00'}

# %%
import pandas as pd
from datetime import datetime,date
nfo_url = 'https://api.shoonya.com/NFO_symbols.txt.zip'
bfo_url = 'https://api.shoonya.com/BFO_symbols.txt.zip'
symbolDf = pd.read_csv(bfo_url if index == 'SENSEX' else nfo_url)
symbolDf['Expiry'] = pd.to_datetime(symbolDf['Expiry']).apply(lambda x: x.date())   
symbolDf
# Out:
#       Exchange   Token  LotSize     Symbol           TradingSymbol  \
# 0          NFO  146751      900  ZYDUSLIFE   ZYDUSLIFE25JUL24P1440
# 1          NFO  146750      900  ZYDUSLIFE   ZYDUSLIFE25JUL24C1440
# 2          NFO  146749      900  ZYDUSLIFE   ZYDUSLIFE25JUL24P1400
# 3          NFO  146748      900  ZYDUSLIFE   ZYDUSLIFE25JUL24C1400
# 4          NFO  146747      900  ZYDUSLIFE   ZYDUSLIFE25JUL24P1360
# ...        ...     ...      ...        ...                     ...
# 80177      NFO   35004       25      NIFTY           NIFTY27JUN24F
# 80178      NFO   35003       15  BANKNIFTY  BANKNIFTY15MAY24P42600
# 80179      NFO   35002       15  BANKNIFTY  BANKNIFTY15MAY24C42600
# 80180      NFO   35001       15  BANKNIFTY  BANKNIFTY15MAY24P33500
# 80181      NFO   35000       15  BANKNIFTY  BANKNIFTY15MAY24C33500
#
#            Expiry Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 0      2024-07-25     OPTSTK         PE      1440.00      0.05          NaN
# 1      2024-07-25     OPTSTK         CE      1440.00      0.05          NaN
# 2      2024-07-25     OPTSTK         PE      1400.00      0.05          NaN
# 3      2024-07-25     OPTSTK         CE      1400.00      0.05          NaN
# 4      2024-07-25     OPTSTK         PE      1360.00      0.05          NaN
# ...           ...        ...        ...          ...       ...          ...
# 80177  2024-06-27     FUTIDX         XX        -0.01      0.05          NaN
# 80178  2024-05-15     OPTIDX         PE     42600.00      0.05          NaN
# 80179  2024-05-15     OPTIDX         CE     42600.00      0.05          NaN
# 80180  2024-05-15     OPTIDX         PE     33500.00      0.05          NaN
# 80181  2024-05-15     OPTIDX         CE     33500.00      0.05          NaN
#
# [80182 rows x 11 columns]

# %%
# def get_expiry_dates(exchange, symbol):
#     import re
#     import datetime
#     sd = api.searchscrip(exchange, symbol)
#     sd = (sd['values'])
#     tsym_values = [Symbol['tsym'] for Symbol in sd]
#     dates = [re.search(r'\d+[A-Z]{3}\d+', tsym).group() for tsym in tsym_values]
#     formatted_dates = [datetime.datetime.strptime(date, '%d%b%y').strftime('%Y-%m-%d') for date in dates]
#     sorted_formatted_dates = sorted(formatted_dates)
#     expiry_dates = sorted_formatted_dates
# #     sorted_dates = [datetime.datetime.strptime(date, '%Y-%m-%d').strftime('%d%b%y').upper() for date in sorted_formatted_dates]
# #     expiry_dates = sorted_dates
#     return expiry_dates

# expiry_date = sensex_expiry_date if index == 'SENSEX' else get_expiry_dates('BFO' if index == 'SENSEX' else 'NFO', index)[0]
# print(expiry_date)

# %%
date_object = datetime.strptime(expiry_date, "%Y-%m-%d").date()

ocdf = symbolDf[(symbolDf.Symbol == ('BSXOPT' if index == 'SENSEX' else index)) & (symbolDf.Expiry == date_object)]
ocdf
# Out:
#       Exchange  Token  LotSize Symbol       TradingSymbol      Expiry  \
# 64557      NFO  53863       25  NIFTY  NIFTY09MAY24P18700  2024-05-09
# 64558      NFO  53862       25  NIFTY  NIFTY09MAY24C18700  2024-05-09
# 64559      NFO  53861       25  NIFTY  NIFTY09MAY24P18650  2024-05-09
# 64560      NFO  53860       25  NIFTY  NIFTY09MAY24C18650  2024-05-09
# 65089      NFO  53001       25  NIFTY  NIFTY09MAY24P18950  2024-05-09
# ...        ...    ...      ...    ...                 ...         ...
# 79374      NFO  35823       25  NIFTY  NIFTY09MAY24C18600  2024-05-09
# 79376      NFO  35821       25  NIFTY  NIFTY09MAY24P18550  2024-05-09
# 79377      NFO  35820       25  NIFTY  NIFTY09MAY24C18550  2024-05-09
# 79378      NFO  35819       25  NIFTY  NIFTY09MAY24P18500  2024-05-09
# 79379      NFO  35818       25  NIFTY  NIFTY09MAY24C18500  2024-05-09
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 64557     OPTIDX         PE      18700.0      0.05          NaN
# 64558     OPTIDX         CE      18700.0      0.05          NaN
# 64559     OPTIDX         PE      18650.0      0.05          NaN
# 64560     OPTIDX         CE      18650.0      0.05          NaN
# 65089     OPTIDX         PE      18950.0      0.05          NaN
# ...          ...        ...          ...       ...          ...
# 79374     OPTIDX         CE      18600.0      0.05          NaN
# 79376     OPTIDX         PE      18550.0      0.05          NaN
# 79377     OPTIDX         CE      18550.0      0.05          NaN
# 79378     OPTIDX         PE      18500.0      0.05          NaN
# 79379     OPTIDX         CE      18500.0      0.05          NaN
#
# [312 rows x 11 columns]

# %%
len(ocdf)
# Out:
# 312

# %%
Cedf =ocdf[(ocdf.OptionType == 'CE')& (ocdf['StrikePrice'] > lower_limit) & (ocdf['StrikePrice'] < upper_limit)] 
Cedf
# Out:
#       Exchange  Token  LotSize Symbol       TradingSymbol      Expiry  \
# 68438      NFO  47005       25  NIFTY  NIFTY09MAY24C23200  2024-05-09
# 68440      NFO  47003       25  NIFTY  NIFTY09MAY24C23150  2024-05-09
# 68442      NFO  47001       25  NIFTY  NIFTY09MAY24C23100  2024-05-09
# 68444      NFO  46999       25  NIFTY  NIFTY09MAY24C23050  2024-05-09
# 68453      NFO  46990       25  NIFTY  NIFTY09MAY24C23000  2024-05-09
# 68461      NFO  46982       25  NIFTY  NIFTY09MAY24C22950  2024-05-09
# 68471      NFO  46972       25  NIFTY  NIFTY09MAY24C22900  2024-05-09
# 68473      NFO  46970       25  NIFTY  NIFTY09MAY24C22850  2024-05-09
# 68475      NFO  46968       25  NIFTY  NIFTY09MAY24C22800  2024-05-09
# 68478      NFO  46965       25  NIFTY  NIFTY09MAY24C22750  2024-05-09
# 68480      NFO  46963       25  NIFTY  NIFTY09MAY24C22700  2024-05-09
# 68486      NFO  46957       25  NIFTY  NIFTY09MAY24C22650  2024-05-09
# 68488      NFO  46955       25  NIFTY  NIFTY09MAY24C22600  2024-05-09
# 68502      NFO  46941       25  NIFTY  NIFTY09MAY24C22550  2024-05-09
# 68504      NFO  46939       25  NIFTY  NIFTY09MAY24C22500  2024-05-09
# 68508      NFO  46935       25  NIFTY  NIFTY09MAY24C22450  2024-05-09
# 68518      NFO  46925       25  NIFTY  NIFTY09MAY24C22400  2024-05-09
# 68522      NFO  46921       25  NIFTY  NIFTY09MAY24C22350  2024-05-09
# 68527      NFO  46916       25  NIFTY  NIFTY09MAY24C22300  2024-05-09
# 68531      NFO  46912       25  NIFTY  NIFTY09MAY24C22250  2024-05-09
# 68537      NFO  46906       25  NIFTY  NIFTY09MAY24C22200  2024-05-09
# 68539      NFO  46904       25  NIFTY  NIFTY09MAY24C22150  2024-05-09
# 68541      NFO  46902       25  NIFTY  NIFTY09MAY24C22100  2024-05-09
# 68547      NFO  46896       25  NIFTY  NIFTY09MAY24C22050  2024-05-09
# 68549      NFO  46894       25  NIFTY  NIFTY09MAY24C22000  2024-05-09
# 68551      NFO  46892       25  NIFTY  NIFTY09MAY24C21950  2024-05-09
# 68555      NFO  46888       25  NIFTY  NIFTY09MAY24C21900  2024-05-09
# 68558      NFO  46885       25  NIFTY  NIFTY09MAY24C21850  2024-05-09
# 68561      NFO  46882       25  NIFTY  NIFTY09MAY24C21800  2024-05-09
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 68438     OPTIDX         CE      23200.0      0.05          NaN
# 68440     OPTIDX         CE      23150.0      0.05          NaN
# 68442     OPTIDX         CE      23100.0      0.05          NaN
# 68444     OPTIDX         CE      23050.0      0.05          NaN
# 68453     OPTIDX         CE      23000.0      0.05          NaN
# 68461     OPTIDX         CE      22950.0      0.05          NaN
# 68471     OPTIDX         CE      22900.0      0.05          NaN
# 68473     OPTIDX         CE      22850.0      0.05          NaN
# 68475     OPTIDX         CE      22800.0      0.05          NaN
# 68478     OPTIDX         CE      22750.0      0.05          NaN
# 68480     OPTIDX         CE      22700.0      0.05          NaN
# 68486     OPTIDX         CE      22650.0      0.05          NaN
# 68488     OPTIDX         CE      22600.0      0.05          NaN
# 68502     OPTIDX         CE      22550.0      0.05          NaN
# 68504     OPTIDX         CE      22500.0      0.05          NaN
# 68508     OPTIDX         CE      22450.0      0.05          NaN
# 68518     OPTIDX         CE      22400.0      0.05          NaN
# 68522     OPTIDX         CE      22350.0      0.05          NaN
# 68527     OPTIDX         CE      22300.0      0.05          NaN
# 68531     OPTIDX         CE      22250.0      0.05          NaN
# 68537     OPTIDX         CE      22200.0      0.05          NaN
# 68539     OPTIDX         CE      22150.0      0.05          NaN
# 68541     OPTIDX         CE      22100.0      0.05          NaN
# 68547     OPTIDX         CE      22050.0      0.05          NaN
# 68549     OPTIDX         CE      22000.0      0.05          NaN
# 68551     OPTIDX         CE      21950.0      0.05          NaN
# 68555     OPTIDX         CE      21900.0      0.05          NaN
# 68558     OPTIDX         CE      21850.0      0.05          NaN
# 68561     OPTIDX         CE      21800.0      0.05          NaN

# %%
Pedf =ocdf[(ocdf.OptionType == 'PE') & (ocdf['StrikePrice'] > lower_limit) & (ocdf['StrikePrice'] < upper_limit)] 
Pedf
# Out:
#       Exchange  Token  LotSize Symbol       TradingSymbol      Expiry  \
# 68437      NFO  47006       25  NIFTY  NIFTY09MAY24P23200  2024-05-09
# 68439      NFO  47004       25  NIFTY  NIFTY09MAY24P23150  2024-05-09
# 68441      NFO  47002       25  NIFTY  NIFTY09MAY24P23100  2024-05-09
# 68443      NFO  47000       25  NIFTY  NIFTY09MAY24P23050  2024-05-09
# 68448      NFO  46995       25  NIFTY  NIFTY09MAY24P23000  2024-05-09
# 68460      NFO  46983       25  NIFTY  NIFTY09MAY24P22950  2024-05-09
# 68470      NFO  46973       25  NIFTY  NIFTY09MAY24P22900  2024-05-09
# 68472      NFO  46971       25  NIFTY  NIFTY09MAY24P22850  2024-05-09
# 68474      NFO  46969       25  NIFTY  NIFTY09MAY24P22800  2024-05-09
# 68476      NFO  46967       25  NIFTY  NIFTY09MAY24P22750  2024-05-09
# 68479      NFO  46964       25  NIFTY  NIFTY09MAY24P22700  2024-05-09
# 68481      NFO  46962       25  NIFTY  NIFTY09MAY24P22650  2024-05-09
# 68487      NFO  46956       25  NIFTY  NIFTY09MAY24P22600  2024-05-09
# 68489      NFO  46954       25  NIFTY  NIFTY09MAY24P22550  2024-05-09
# 68503      NFO  46940       25  NIFTY  NIFTY09MAY24P22500  2024-05-09
# 68505      NFO  46938       25  NIFTY  NIFTY09MAY24P22450  2024-05-09
# 68509      NFO  46934       25  NIFTY  NIFTY09MAY24P22400  2024-05-09
# 68519      NFO  46924       25  NIFTY  NIFTY09MAY24P22350  2024-05-09
# 68526      NFO  46917       25  NIFTY  NIFTY09MAY24P22300  2024-05-09
# 68528      NFO  46915       25  NIFTY  NIFTY09MAY24P22250  2024-05-09
# 68532      NFO  46911       25  NIFTY  NIFTY09MAY24P22200  2024-05-09
# 68538      NFO  46905       25  NIFTY  NIFTY09MAY24P22150  2024-05-09
# 68540      NFO  46903       25  NIFTY  NIFTY09MAY24P22100  2024-05-09
# 68544      NFO  46899       25  NIFTY  NIFTY09MAY24P22050  2024-05-09
# 68548      NFO  46895       25  NIFTY  NIFTY09MAY24P22000  2024-05-09
# 68550      NFO  46893       25  NIFTY  NIFTY09MAY24P21950  2024-05-09
# 68552      NFO  46891       25  NIFTY  NIFTY09MAY24P21900  2024-05-09
# 68556      NFO  46887       25  NIFTY  NIFTY09MAY24P21850  2024-05-09
# 68559      NFO  46884       25  NIFTY  NIFTY09MAY24P21800  2024-05-09
#
#       Instrument OptionType  StrikePrice  TickSize  Unnamed: 10
# 68437     OPTIDX         PE      23200.0      0.05          NaN
# 68439     OPTIDX         PE      23150.0      0.05          NaN
# 68441     OPTIDX         PE      23100.0      0.05          NaN
# 68443     OPTIDX         PE      23050.0      0.05          NaN
# 68448     OPTIDX         PE      23000.0      0.05          NaN
# 68460     OPTIDX         PE      22950.0      0.05          NaN
# 68470     OPTIDX         PE      22900.0      0.05          NaN
# 68472     OPTIDX         PE      22850.0      0.05          NaN
# 68474     OPTIDX         PE      22800.0      0.05          NaN
# 68476     OPTIDX         PE      22750.0      0.05          NaN
# 68479     OPTIDX         PE      22700.0      0.05          NaN
# 68481     OPTIDX         PE      22650.0      0.05          NaN
# 68487     OPTIDX         PE      22600.0      0.05          NaN
# 68489     OPTIDX         PE      22550.0      0.05          NaN
# 68503     OPTIDX         PE      22500.0      0.05          NaN
# 68505     OPTIDX         PE      22450.0      0.05          NaN
# 68509     OPTIDX         PE      22400.0      0.05          NaN
# 68519     OPTIDX         PE      22350.0      0.05          NaN
# 68526     OPTIDX         PE      22300.0      0.05          NaN
# 68528     OPTIDX         PE      22250.0      0.05          NaN
# 68532     OPTIDX         PE      22200.0      0.05          NaN
# 68538     OPTIDX         PE      22150.0      0.05          NaN
# 68540     OPTIDX         PE      22100.0      0.05          NaN
# 68544     OPTIDX         PE      22050.0      0.05          NaN
# 68548     OPTIDX         PE      22000.0      0.05          NaN
# 68550     OPTIDX         PE      21950.0      0.05          NaN
# 68552     OPTIDX         PE      21900.0      0.05          NaN
# 68556     OPTIDX         PE      21850.0      0.05          NaN
# 68559     OPTIDX         PE      21800.0      0.05          NaN

# %%
# expiry_date
# from datetime import datetime
# date_obj = datetime.strptime(expiry_date, "%Y-%m-%d")
# today = datetime.now()
# diff = (date_obj - today).days + 1
# print(diff)

# %%
ltp1 = buy_premium[index][diff]
ltp = sell_premium[index][diff]

print(ltp1)
print(ltp)
strikeList = []
for i in Cedf.index:
    strikeInfo = Cedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
    
strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf1['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
ce_buy = strikedf1.iloc[0].tsym
print(ce_buy)

strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
ce_sell = strikedf.iloc[0].tsym
print(ce_sell)
ce_sl = 2*(strikedf.iloc[0].lp)
print(ce_sl)
# Out:
# 5
# 40
# NIFTY09MAY24C23200
# NIFTY09MAY24C22800
# 87.2

# %%
ltp = buy_premium[index][diff]
ltp1 = sell_premium[index][diff]

print(ltp)
print(ltp1)

strikeList = []
for i in Pedf.index:
    strikeInfo = Pedf.loc[i]
    res = api.get_quotes(exchange='NFO', token=str(strikeInfo.Token))
    res = {'tsym': res['tsym'], 'lp': float(res['lp']),'lotSize':strikeInfo.LotSize,'token':res['token']}
    strikeList.append(res)
strikedf = pd.DataFrame(strikeList)
strikedf.sort_values(by = 'lp',inplace = True)
strikedf['diff'] = abs(strikedf['lp'] - ltp)
strikedf.sort_values(by = 'diff',inplace = True)
pe_buy = strikedf.iloc[0].tsym
print(pe_buy)

strikedf1 = pd.DataFrame(strikeList)
strikedf1.sort_values(by = 'lp',inplace = True)
strikedf1['diff'] = abs(strikedf['lp'] - ltp1)
strikedf1.sort_values(by = 'diff',inplace = True)
pe_sell = strikedf1.iloc[0].tsym
print(pe_sell)
pe_sl = 2*(strikedf1.iloc[0].lp)
print(pe_sl)
# Out:
# 5
# 40
# NIFTY09MAY24P21800
# NIFTY09MAY24P22200
# 79.5

# %%
print(ce_buy)
print(pe_buy)
print(ce_sell)
print(pe_sell)
# Out:
# NIFTY09MAY24C23200
# NIFTY09MAY24P21800
# NIFTY09MAY24C22800
# NIFTY09MAY24P22200

# %%
import re

def get_new_strike(original_string, change):
    import re
    match = re.search(r'\d+$', original_string)

    if match:
        # Extracted number
        number = int(match.group())

        # Add 100 to the number
        new_number = number + change

        # Replace the old number with the new number in the original string
        new_string = original_string[:match.start()] + str(new_number)
        
        print("Original string:", original_string)
        print("New string:", new_string)
        return new_string        
    else:
        print("Strike not in proper format")

# %%
# call buy leg
ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=ce_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24050400008625'

# %%
# put buy leg
ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=pe_buy, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24050400008626'

# %%
# call sell leg
ret = api.place_order(buy_or_sell='S', product_type='M',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24050400008627'

# %%
# put sell leg
ret = api.place_order(buy_or_sell='S', product_type='M',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']
# Out:
# '24050400008628'

# %%
# call sl order
ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']

# %%
# put sl order
ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']

# %%
print(ce_sl_orderid)
print(pe_sl_orderid)
# Out:
# 24050400008629
# 24050400008630

# %%
# call adj1
ret = api.cancel_order(orderno=ce_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
ce_sell = new_ce_strike

ret = api.place_order(buy_or_sell='S', product_type='M',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=ce_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
                        retention='DAY', remarks='my_order_001')

ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"09:49:25 05-05-2024","stat":"Ok","result":"24050400008641"}
# Original string: NIFTY09MAY24C22650
# New string: NIFTY09MAY24C22600

# %%
# put adj1
ret = api.cancel_order(orderno=pe_sl_orderid)

ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
pe_sell = new_pe_strike

ret = api.place_order(buy_or_sell='S', product_type='M',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='MKT',
                        retention='DAY', remarks='my_order_001')

ret['norenordno']

ret = api.place_order(buy_or_sell='B', product_type='M',
                        exchange='NFO', tradingsymbol=pe_sell, 
                        quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
                        retention='DAY', remarks='my_order_001')

pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"09:50:32 05-05-2024","stat":"Ok","result":"24050400008656"}
# Original string: NIFTY09MAY24P22400
# New string: NIFTY09MAY24P22450

# %%
# # call adj2
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"09:39:23 05-05-2024","stat":"Ok","result":"24050400008582"}
# Original string: BANKNIFTY08MAY24C49900
# New string: BANKNIFTY08MAY24C49800

# %%
# # call adj3
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:04 14-04-2024","stat":"Ok","result":"24041300004646"}
# Original string: BANKNIFTY16APR24C49000
# New string: BANKNIFTY16APR24C48900

# %%
# # call adj4
# ret = api.cancel_order(orderno=ce_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_ce_strike = get_new_strike(ce_sell, -1*changes_in_strike[id])
# ce_sell = new_ce_strike

# ret = api.place_order(buy_or_sell='S', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=ce_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=ce_sl+2, trigger_price=ce_sl,
#                         retention='DAY', remarks='my_order_001')

# ce_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:04 14-04-2024","stat":"Ok","result":"24041300004649"}
# Original string: BANKNIFTY16APR24C48900
# New string: BANKNIFTY16APR24C48800

# %%
# # put adj2
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:06 14-04-2024","stat":"Ok","result":"24041300004655"}
# Original string: BANKNIFTY16APR24P48200
# New string: BANKNIFTY16APR24P48300

# %%
# # put adj3
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:07 14-04-2024","stat":"Ok","result":"24041300004658"}
# Original string: BANKNIFTY16APR24P48300
# New string: BANKNIFTY16APR24P48400

# %%
# # put adj4
# ret = api.cancel_order(orderno=pe_sl_orderid)

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# new_pe_strike = get_new_strike(pe_sell, changes_in_strike[id])
# pe_sell = new_pe_strike

# ret = api.place_order(buy_or_sell='S', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='MKT',
#                         retention='DAY', remarks='my_order_001')

# ret['norenordno']

# ret = api.place_order(buy_or_sell='B', product_type='M',
#                         exchange='NFO', tradingsymbol=pe_sell, 
#                         quantity=lots*lot_size, discloseqty=0,price_type='SL-LMT', price=pe_sl+2, trigger_price=pe_sl,
#                         retention='DAY', remarks='my_order_001')

# pe_sl_orderid = ret['norenordno']
# Out:
# https://api.shoonya.com/NorenWClientTP//CancelOrder
# {"request_time":"10:33:07 14-04-2024","stat":"Ok","result":"24041300004661"}
# Original string: BANKNIFTY16APR24P48400
# New string: BANKNIFTY16APR24P48500
